# %%
import pandas as pd
import numpy as np
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

# %%
df_temp_out = pd.read_csv('outdoor_temperature.csv')  
df_temp_in = pd.read_csv('indoor_temperature.csv')  
df_heat = pd.read_csv('heating_consumption.csv')  

df_combined_tempout = pd.concat([df_temp_out ,df_heat], axis=1)  
df_combined_tempin = pd.concat([ df_temp_in, df_heat], axis=1)  

date_range = pd.date_range(start='2021-01-01', end='2022-12-28', freq='D')

df_combined_tempout['date'] = date_range
df_combined_tempin['date'] = date_range

print(df_combined_tempout)
# Out:
#      5.2000  4.2000  4.4000  3.3000  1.7000  2.8000  1.9000  1.9000.1  2.0000  \
# 0       0.9     1.4     1.6     0.8    -0.4    -1.1    -1.2      -0.7    -0.7
# 1       0.8     0.9     0.9     1.1     1.3     1.3     0.1      -0.6     1.9
# 2       0.5     0.2     0.1     0.6     0.3    -0.4    -0.4       0.1     0.8
# 3       1.9     1.7     1.3     1.5     1.5     1.3     1.0       0.9     1.1
# 4       1.4     1.5     1.5     1.5     1.4     1.5     1.5       1.4     1.7
# ..      ...     ...     ...     ...     ...     ...     ...       ...     ...
# 722     7.1     7.2     7.6    10.5    11.7     8.5     7.7       8.0    11.0
# 723     8.1     7.8     6.9     7.0     5.8     7.8     6.5       7.5     9.1
# 724    10.9    11.0    10.7    10.9    10.9    10.6    10.5      10.7    11.0
# 725     6.5     6.9     6.3     5.8     4.9     4.8     4.0       5.1     7.3
# 726     9.3     8.9     8.7     8.7     9.2     9.1    10.3       9.1     9.8
#
#      2.3000  ...  0.0000.15  0.0000.16  0.0000.17  0.0000.18  0.0000.19  \
# 0      -0.1  ...      0.000      0.000      0.000        0.0        0.0
# 1       3.6  ...      0.000      0.000      0.000        0.0        0.0
# 2       2.4  ...      0.109      0.318      0.001        0.0        0.0
# 3       1.6  ...      0.823      0.808      0.264        0.0        0.0
# 4       2.2  ...      0.120      0.328      0.070        0.0        0.0
# ..      ...  ...        ...        ...        ...        ...        ...
# 722    12.6  ...      0.000      0.000      0.000        0.0        0.0
# 723    11.9  ...      0.000      0.000      0.000        0.0        0.0
# 724    11.2  ...      0.000      0.000      0.000        0.0        0.0
# 725     9.5  ...      0.000      0.000      0.000        0.0        0.0
# 726    11.2  ...      0.000      0.000      0.000        0.0        0.0
#
#      0.0000.20  0.0000.21  0.0000.22  0.0000.23       date
# 0          0.0        0.0        0.0        0.0 2021-01-01
# 1          0.0        0.0        0.0        0.0 2021-01-02
# 2          0.0        0.0        0.0        0.0 2021-01-03
# 3          0.0        0.0        0.0        0.0 2021-01-04
# 4          0.0        0.0        0.0        0.0 2021-01-05
# ..         ...        ...        ...        ...        ...
# 722        0.0        0.0        0.0        0.0 2022-12-24
# 723        0.0        0.0        0.0        0.0 2022-12-25
# 724        0.0        0.0        0.0        0.0 2022-12-26
# 725        0.0        0.0        0.0        0.0 2022-12-27
# 726        0.0        0.0        0.0        0.0 2022-12-28
#
# [727 rows x 49 columns]

# %%
df_no_heating = df_combined_tempout[df_combined_tempout.iloc[:, -25:-1].sum(axis=1) == 0]  
df_heating_tempout = df_combined_tempout[df_combined_tempout.iloc[:, -25:-1].sum(axis=1) != 0]      

df_heating_tempout = df_heating_tempout.reset_index(drop=True)

#print(df_heating_tempout)
df_heating2_tempout = df_heating_tempout.drop(df_heating_tempout.columns[-25:], axis=1)

df_no_heating2 = df_combined_tempin[df_combined_tempin.iloc[:, -25:-1].sum(axis=1) == 0]  
df_heating_tempin = df_combined_tempin[df_combined_tempin.iloc[:, -25:-1].sum(axis=1) != 0]      

df_heating_tempin = df_heating_tempin.reset_index(drop=True)

#print(df_heating_tempin)
df_heating2_tempin = df_heating_tempin.drop(df_heating_tempin.columns[-25:], axis=1)

# %%
def apply_kmeans(data, n_clusters=3):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    data['cluster'] = kmeans.fit_predict(data)
    
    return kmeans, data

# %%
def plot_clusters_single_variable(data_normalized, cluster_assignments, kmeans, column_index, y_label="Valeur"):
    fig, axes = plt.subplots(2, 2, figsize=(14, 12))

    all_values = data_normalized.iloc[:, column_index:].values.flatten()
    y_min, y_max = np.min(all_values), np.max(all_values)

    for cluster_id in range(kmeans.n_clusters):
        cluster_data = data_normalized[cluster_assignments == cluster_id].iloc[:, column_index:]
        cluster_center = kmeans.cluster_centers_[cluster_id, column_index:-1]

        for _, row in cluster_data.iterrows():
            axes[cluster_id // 2, cluster_id % 2].plot(range(24), row, color='gray', alpha=0.5)

        axes[cluster_id // 2, cluster_id % 2].plot(range(24), cluster_center, color='red', linewidth=3, label=f"Centre du cluster {cluster_id}")
        
        axes[cluster_id // 2, cluster_id % 2].set_title(f"Séries temporelles du Cluster {cluster_id}")
        axes[cluster_id // 2, cluster_id % 2].set_xlabel("Heures")
        axes[cluster_id // 2, cluster_id % 2].set_ylabel(y_label)
        axes[cluster_id // 2, cluster_id % 2].set_ylim([y_min, y_max])
        axes[cluster_id // 2, cluster_id % 2].grid(True)

    plt.tight_layout()
    plt.show()

# %%
print(df_heating_tempout)
# Out:
#      5.2000  4.2000  4.4000  3.3000  1.7000  2.8000  1.9000  1.9000.1  2.0000  \
# 0       0.5     0.2     0.1     0.6     0.3    -0.4    -0.4       0.1     0.8
# 1       1.9     1.7     1.3     1.5     1.5     1.3     1.0       0.9     1.1
# 2       1.4     1.5     1.5     1.5     1.4     1.5     1.5       1.4     1.7
# 3      -3.0    -3.0    -3.4    -3.7    -4.7    -4.6    -4.6      -4.6    -3.0
# 4      -3.6    -4.2    -3.8    -4.8    -4.8    -5.0    -5.1      -4.9    -2.4
# ..      ...     ...     ...     ...     ...     ...     ...       ...     ...
# 240    12.1    12.1    12.3    12.3    12.4    12.2    12.3      12.4    12.8
# 241    12.6    12.2    12.0    12.6    12.7    12.6    12.9      13.1    13.3
# 242    12.3    11.9    11.9    11.1    10.8    10.5    10.3      10.5    11.0
# 243    10.8    10.6    11.1     9.3     9.0     7.9     8.6       9.0    10.6
# 244    12.2    10.8    10.6    10.2     9.5     9.3     8.9       8.9    10.8
#
#      2.3000  ...  0.0000.16  0.0000.17  0.0000.18  0.0000.19  0.0000.20  \
# 0       2.4  ...      0.318      0.001        0.0        0.0        0.0
# 1       1.6  ...      0.808      0.264        0.0        0.0        0.0
# 2       2.2  ...      0.328      0.070        0.0        0.0        0.0
# 3      -2.1  ...      0.732      0.063        0.0        0.0        0.0
# 4       0.1  ...      0.269      0.330        0.0        0.0        0.0
# ..      ...  ...        ...        ...        ...        ...        ...
# 240    14.9  ...      0.000      0.000        0.0        0.0        0.0
# 241    13.8  ...      0.000      0.000        0.0        0.0        0.0
# 242    13.0  ...      0.000      0.000        0.0        0.0        0.0
# 243    13.0  ...      0.007      0.007        0.0        0.0        0.0
# 244    13.2  ...      0.000      0.000        0.0        0.0        0.0
#
#      0.0000.21  0.0000.22  0.0000.23       date  cluster
# 0          0.0        0.0        0.0 2021-01-03        2
# 1          0.0        0.0        0.0 2021-01-04        2
# 2          0.0        0.0        0.0 2021-01-05        2
# 3          0.0        0.0        0.0 2021-01-06        2
# 4          0.0        0.0        0.0 2021-01-07        2
# ..         ...        ...        ...        ...      ...
# 240        0.0        0.0        0.0 2022-12-18        0
# 241        0.0        0.0        0.0 2022-12-19        0
# 242        0.0        0.0        0.0 2022-12-20        0
# 243        0.0        0.0        0.0 2022-12-21        0
# 244        0.0        0.0        0.0 2022-12-22        0
#
# [245 rows x 50 columns]

# %%
kmeans, data_tempout_with_cluster = apply_kmeans(df_heating2_tempout, 4)

df_heating_tempout["cluster"]=data_tempout_with_cluster["cluster"]

# %%
kmeans, data_tempin_with_cluster = apply_kmeans(df_heating2_tempin, 4)

df_heating_tempin["cluster"]=data_tempin_with_cluster["cluster"]

# %%
df_heating2_tempout2=df_heating2_tempout.drop(columns=["cluster"])
plot_clusters_single_variable(df_heating2_tempout2, df_heating2_tempout["cluster"],kmeans, column_index=0, y_label="outdoor_temperature")

# %%
labels = df_heating2_tempout['cluster'] 
df_heating2_tempout=df_heating2_tempout.drop(columns=["cluster"])

sil_score = silhouette_score(df_heating2_tempout, labels, metric='euclidean')
db_score = davies_bouldin_score(df_heating2_tempout, labels)

print(f"Davies-Bouldin Index: {db_score}")
print(f"Silhouette Score: {sil_score}")
# Out:
# Davies-Bouldin Index: 0.9257481613676091
# Silhouette Score: 0.33986822439884057

# %%
df_heating2_tempin2=df_heating2_tempin.drop(columns=["cluster"])

plot_clusters_single_variable(df_heating2_tempin2, df_heating2_tempin["cluster"],kmeans, column_index=0, y_label="indoor_temperature")

# %%
labels = df_heating2_tempin['cluster'] 
df_heating2_tempin=df_heating2_tempin.drop(columns=["cluster"])

sil_score = silhouette_score(df_heating2_tempin, labels, metric='euclidean')
db_score = davies_bouldin_score(df_heating2_tempin, labels)

print(f"Davies-Bouldin Index: {db_score}")
print(f"Silhouette Score: {sil_score}")
# Out:
# Davies-Bouldin Index: 0.7597626880268699
# Silhouette Score: 0.4124287926009478
