# %%
import pandas as pd

# %%
df_118=pd.read_csv("./Dataset_20240601-20250428/01Jun2024-28Avr2025_Salle_118.csv")

# %%
df_118.columns
# Out:
# Index(['Timestamp', 'EWATCH_3104_OccupancyTime_u6_118',
#        'EWATCH_3104_OccupancyBinaire_u6_118', 'EWATCH_3104_Temperature_u6_118',
#        'EWATCH_3104_Humidity_u6_118', 'EWATCH_3104_Co2_u6_118'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

colonnes_originales = ['EWATCH_3104_Temperature_u6_118', 'EWATCH_3104_Humidity_u6_118', 'EWATCH_3104_Co2_u6_118','EWATCH_3104_OccupancyBinaire_u6_118']

noms_affiches = ['Température', 'Humidité', 'CO₂', 'Occupation']

df1=df_118.dropna()
matrice_corr = df1[colonnes_originales].corr()

# Création de la heatmap avec noms personnalisés
plt.figure(figsize=(8,6))
sns.heatmap(
    matrice_corr,
    annot=True,
    cmap='coolwarm',
    xticklabels=noms_affiches,
    yticklabels=noms_affiches
)
plt.title("Matrice de Corrélation")
plt.show()

# %%
Occ = df_118[['Timestamp', 'EWATCH_3104_OccupancyBinaire_u6_118']]
Occ['Timestamp'] = pd.to_datetime(Occ['Timestamp'])
n_days = len(Occ) // 144
Occ_clean = Occ.iloc[:n_days * 144]
dates = Occ_clean['Timestamp'].dt.date[::144].reset_index(drop=True)
reshaped = Occ_clean['EWATCH_3104_OccupancyBinaire_u6_118'].to_numpy().reshape(n_days, 144)
df_Occ = pd.DataFrame(reshaped)
df_Occ['Date'] = dates  
df_Occ = df_Occ.set_index('Date')

jours_occupes = df_Occ.iloc[:, 1:].sum(axis=1) != 0
df_Occ_filtré = df_Occ[jours_occupes]
valeurs_flat = df_Occ_filtré.values
occupation_flat = valeurs_flat.flatten()
dates_dupliquees = df_Occ_filtré.index.repeat(144)
df_occupation_finale = pd.DataFrame({
    'Date': dates_dupliquees,
    'Occupation': occupation_flat
})

colonnes_capteurs =['EWATCH_3104_Temperature_u6_118', 'EWATCH_3104_Humidity_u6_118', 'EWATCH_3104_Co2_u6_118']

# On filtre et reshape chaque colonne comme pour l'occupation
dfs_aplatis = []

for col in colonnes_capteurs:
    # On repart de la colonne + timestamp
    capteur_df = df_118[['Timestamp', col]].copy()
    capteur_df['Timestamp'] = pd.to_datetime(capteur_df['Timestamp'])

    # Découpage sur n_days
    capteur_clean = capteur_df.iloc[:n_days * 144]
    reshaped = capteur_clean[col].to_numpy().reshape(n_days, 144)

    # On en fait un DataFrame avec les mêmes dates
    df_capteur = pd.DataFrame(reshaped)
    df_capteur['Date'] = dates
    df_capteur = df_capteur.set_index('Date')

    # On garde uniquement les jours occupés
    df_capteur_filtré = df_capteur[jours_occupes]

    # Flatten
    valeurs_flat = df_capteur_filtré.values.flatten()

    # Ajouter dans une liste
    dfs_aplatis.append(valeurs_flat)

# Construire le DataFrame final en les combinant
df_autres_valeurs = pd.DataFrame({
    'Température': dfs_aplatis[0],
    'Humidité': dfs_aplatis[1],
    'CO₂': dfs_aplatis[2],
    
})

# Concaténer avec df_occupation_finale
df_complet = pd.concat([df_occupation_finale.reset_index(drop=True),
                        df_autres_valeurs], axis=1)

matrice_corr = df_complet.iloc[:,1:].corr()

# Afficher la heatmap
plt.figure(figsize=(8,6))
sns.heatmap(
    matrice_corr,
    annot=True,
    cmap='coolwarm',
)
plt.title("Matrice de Corrélation filtrée sur la plage choisie")
plt.show()
# Out:
# C:\Users\toubia\AppData\Local\Temp\ipykernel_4264\2836405535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Occ['Timestamp'] = pd.to_datetime(Occ['Timestamp'])

# %%
temp = df_118[['EWATCH_3104_Temperature_u6_118']]
n_days = len(temp) // 144
temp_clean = temp.iloc[:n_days * 144]  # on coupe les valeurs en trop
reshaped = temp_clean.to_numpy().reshape(n_days, 144)
df_temp = pd.DataFrame(reshaped)


Hum = df_118[['EWATCH_3104_Humidity_u6_118']]
n_days = len(Hum) // 144
Hum_clean = Hum.iloc[:n_days * 144]  # on coupe les valeurs en trop
reshaped = Hum_clean.to_numpy().reshape(n_days, 144)
df_hum = pd.DataFrame(reshaped)

Co2 = df_118[['EWATCH_3104_Co2_u6_118']]
n_days = len(Co2) // 144
Co2_clean = Co2.iloc[:n_days * 144]  # on coupe les valeurs en trop
reshaped = Co2_clean.to_numpy().reshape(n_days, 144)
df_co2 = pd.DataFrame(reshaped)


Occ = df_118[['EWATCH_3104_OccupancyBinaire_u6_118']]
n_days = len(Occ) // 144
Occ_clean = Occ.iloc[:n_days * 144]  # on coupe les valeurs en trop
reshaped = Occ_clean.to_numpy().reshape(n_days, 144)
df_Occ = pd.DataFrame(reshaped)

# %%
len(df_Occ)
# Out:
# 330

# %%
df_Occ.isna().sum().sum()
# Out:
# 0

# %%
((df_Occ.sum(axis=1))!=0).sum()
# Out:
# 197

# %%
len(df_Noise)
# Out:
# 300

# %%
for df in [df_temp, df_hum, df_co2]:
    df.interpolate(method='linear', axis=1, limit_direction='both', inplace=True)
    df.ffill(axis=1, inplace=True)
    df.bfill(axis=1, inplace=True)
    

for df in [df_temp, df_hum, df_co2]:
    df.dropna(how='all', inplace=True)

# %%
import matplotlib.pyplot as plt
for i in range(df_Occ.shape[0]):
    plt.plot(range(144), df_Occ.iloc[i])  # tracer la 1ère journée
plt.title("Évolution de l'occupation ")
plt.xlabel("Pas de temps (10 min)")
plt.ylabel("Occupation")
plt.grid(True)
plt.show()

# %%
df_Occ2=df_Occ.dropna()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed

def train_lstm_model(X, Y, input_shape, test_size=0.2, epochs=20, batch_size=16, threshold=0.5):
    # Split
    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=test_size, random_state=42, shuffle=True
    )

    # Modèle
    model = Sequential([
        LSTM(64, activation='tanh', return_sequences=True, input_shape=input_shape),
        TimeDistributed(Dense(1, activation='sigmoid'))
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Entraînement
    history = model.fit(
        X_train, Y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, Y_test),
        verbose=1
    )

    # Prédictions sur le test set
    Y_pred = model.predict(X_test)

    # Optionnel : appliquer le seuil si tu veux des prédictions binaires
    Y_pred_binary = (Y_pred > threshold).astype(int)

    # Retourner les vraies valeurs, prédictions, et X_test pour visualisation
    return X_test, Y_test, Y_pred, Y_pred_binary, history

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.7856 - loss: 0.3836 - val_accuracy: 0.7951 - val_loss: 0.3752
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7899 - loss: 0.3823 - val_accuracy: 0.7880 - val_loss: 0.3818
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.7897 - loss: 0.3796 - val_accuracy: 0.7880 - val_loss: 0.3770
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7886 - loss: 0.3849 - val_accuracy: 0.7731 - val_loss: 0.3927
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.7823 - loss: 0.3920 - val_accuracy: 0.7969 - val_loss: 0.3780
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7873 - loss: 0.3828 - val_accuracy: 0.7969 - val_loss: 0.3844
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7890 - loss: 0.3808 - val_accuracy: 0.7944 - val_loss: 0.3793
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7918 - loss: 0.3775 - val_accuracy: 0.7932 - val_loss: 0.3755
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7909 - loss: 0.3829 - val_accuracy: 0.7580 - val_loss: 0.3988
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7868 - loss: 0.3910 - val_accuracy: 0.7891 - val_loss: 0.3837
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7838 - loss: 0.3842 - val_accuracy: 0.7925 - val_loss: 0.3910
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.7844 - loss: 0.3865 - val_accuracy: 0.7955 - val_loss: 0.3769
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.7966 - loss: 0.3757 - val_accuracy: 0.7731 - val_loss: 0.3846
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.7876 - loss: 0.3841 - val_accuracy: 0.7934 - val_loss: 0.3776
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7922 - loss: 0.3839 - val_accuracy: 0.7865 - val_loss: 0.3935
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step

# %%
plt.plot(Y_test2[16].flatten(), label='Vrai')
plt.plot(Y_pred_binary2[16].flatten(), label='Prédit (binaire)', linestyle='--')
plt.legend()
plt.show()

# %%
len(df_filtered)
# Out:
# 197

# %%
import numpy as np

# %%
scaler = MinMaxScaler()
df_temp_norm = pd.DataFrame(scaler.fit_transform(df_temp), columns=df_temp.columns, index=df_temp.index)
df_hum_norm = pd.DataFrame(scaler.fit_transform(df_hum), columns=df_hum.columns, index=df_hum.index)

df_combined = pd.concat([df_temp_norm,df_hum_norm ,df_Occ], axis=1, join='inner')

sum_occupation = df_combined.iloc[:, -144:].sum(axis=1)
df_filtered = df_combined[sum_occupation != 0]


temp = df_filtered.iloc[:, 0:144].to_numpy()      
hum = df_filtered.iloc[:, 144:288].to_numpy() 

X = np.stack((temp,hum), axis=2)  

Y = df_filtered.iloc[:, -144:].to_numpy()

X_test3, Y_test3, Y_pred3, Y_pred_binary3, history3 = train_lstm_model(
    X,
    Y,
    input_shape=(144, 2),
    epochs=100,
    batch_size=16,
    threshold=0.5 
)
# Out:
# Epoch 1/100
# C:\Users\toubia\anaconda3\envs\notebook\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.3809 - loss: 0.7174 - val_accuracy: 0.7024 - val_loss: 0.6368
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7482 - loss: 0.6018 - val_accuracy: 0.7024 - val_loss: 0.6423
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7273 - loss: 0.6055 - val_accuracy: 0.7024 - val_loss: 0.6247
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7378 - loss: 0.5895 - val_accuracy: 0.7024 - val_loss: 0.6239
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.7417 - loss: 0.5837 - val_accuracy: 0.7024 - val_loss: 0.6242
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7436 - loss: 0.5798 - val_accuracy: 0.7024 - val_loss: 0.6201
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7381 - loss: 0.5828 - val_accuracy: 0.7024 - val_loss: 0.6149
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7440 - loss: 0.5729 - val_accuracy: 0.7024 - val_loss: 0.6017
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7352 - loss: 0.5664 - val_accuracy: 0.7024 - val_loss: 0.5758
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7524 - loss: 0.5348 - val_accuracy: 0.7024 - val_loss: 0.5605
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7278 - loss: 0.5440 - val_accuracy: 0.7024 - val_loss: 0.5449
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7824 - loss: 0.3771 - val_accuracy: 0.7878 - val_loss: 0.3822
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7793 - loss: 0.3918 - val_accuracy: 0.7946 - val_loss: 0.3832
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7784 - loss: 0.3842 - val_accuracy: 0.7880 - val_loss: 0.3869
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7750 - loss: 0.3978 - val_accuracy: 0.7967 - val_loss: 0.3828
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7832 - loss: 0.3862 - val_accuracy: 0.7891 - val_loss: 0.3832
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7837 - loss: 0.3862 - val_accuracy: 0.7894 - val_loss: 0.3814
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7838 - loss: 0.3864 - val_accuracy: 0.7936 - val_loss: 0.3824
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7771 - loss: 0.3872 - val_accuracy: 0.7948 - val_loss: 0.3888
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7865 - loss: 0.3803 - val_accuracy: 0.7955 - val_loss: 0.3797
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7898 - loss: 0.3849 - val_accuracy: 0.7859 - val_loss: 0.3896
# WARNING:tensorflow:5 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000211EAFF6D40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000211EAFF6D40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step

# %%
scaler = MinMaxScaler()
df_temp_norm = pd.DataFrame(scaler.fit_transform(df_temp), columns=df_temp.columns, index=df_temp.index)
df_hum_norm = pd.DataFrame(scaler.fit_transform(df_hum), columns=df_hum.columns, index=df_hum.index)
df_co2_norm = pd.DataFrame(scaler.fit_transform(df_co2), columns=df_co2.columns, index=df_co2.index)

df_combined = pd.concat([df_temp_norm,df_hum_norm,df_co2_norm ,df_Occ], axis=1, join='inner')

sum_occupation = df_combined.iloc[:, -144:].sum(axis=1)
df_filtered = df_combined[sum_occupation != 0]


temp = df_filtered.iloc[:, 0:144].to_numpy()      
hum = df_filtered.iloc[:, 144:288].to_numpy() 
co2 = df_filtered.iloc[:, 288:432].to_numpy()  

X = np.stack((temp,hum,co2), axis=2)  

Y = df_filtered.iloc[:, -144:].to_numpy()

X_test3, Y_test3, Y_pred3, Y_pred_binary3, history3 = train_lstm_model(
    X,
    Y,
    input_shape=(144, 3),
    epochs=100,
    batch_size=16,
    threshold=0.5 
)
# Out:
# Epoch 1/100
# C:\Users\toubia\anaconda3\envs\notebook\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 285ms/step - accuracy: 0.7328 - loss: 0.6401 - val_accuracy: 0.7024 - val_loss: 0.6317
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7467 - loss: 0.5839 - val_accuracy: 0.7024 - val_loss: 0.6156
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7370 - loss: 0.5857 - val_accuracy: 0.6913 - val_loss: 0.6068
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7289 - loss: 0.5776 - val_accuracy: 0.6938 - val_loss: 0.6036
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7490 - loss: 0.5441 - val_accuracy: 0.7016 - val_loss: 0.5630
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7540 - loss: 0.5281 - val_accuracy: 0.7045 - val_loss: 0.5667
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7541 - loss: 0.5114 - val_accuracy: 0.7207 - val_loss: 0.5463
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7600 - loss: 0.4943 - val_accuracy: 0.7410 - val_loss: 0.5494
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7665 - loss: 0.4975 - val_accuracy: 0.7255 - val_loss: 0.5341
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.7782 - loss: 0.4805 - val_accuracy: 0.7306 - val_loss: 0.5210
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7664 - loss: 0.4696 - val_accuracy: 0.7411 - val_loss: 0.5074
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7835 - loss: 0.4680 - val_accuracy: 0.7392 - val_loss: 0.4933
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7882 - loss: 0.4367 - val_accuracy: 0.7639 - val_loss: 0.4527
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8049 - loss: 0.4073 - val_accuracy: 0.7809 - val_loss: 0.4288
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8282 - loss: 0.3784 - val_accuracy: 0.7901 - val_loss: 0.4160
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8645 - loss: 0.2881 - val_accuracy: 0.8290 - val_loss: 0.4191
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8713 - loss: 0.2866 - val_accuracy: 0.8293 - val_loss: 0.4174
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8617 - loss: 0.2971 - val_accuracy: 0.8380 - val_loss: 0.4040
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8670 - loss: 0.2881 - val_accuracy: 0.8399 - val_loss: 0.4124
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8625 - loss: 0.2983 - val_accuracy: 0.8323 - val_loss: 0.4118
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8724 - loss: 0.2886 - val_accuracy: 0.8398 - val_loss: 0.4050
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step

# %%
scaler = MinMaxScaler()
df_temp_norm = pd.DataFrame(scaler.fit_transform(df_temp), columns=df_temp.columns, index=df_temp.index)
df_co2_norm = pd.DataFrame(scaler.fit_transform(df_co2), columns=df_co2.columns, index=df_co2.index)

df_combined = pd.concat([df_temp_norm,df_co2_norm ,df_Occ], axis=1, join='inner')

sum_occupation = df_combined.iloc[:, -144:].sum(axis=1)
df_filtered = df_combined[sum_occupation != 0]


temp = df_filtered.iloc[:, 0:144].to_numpy()      
co2 = df_filtered.iloc[:, 144:288].to_numpy() 

X = np.stack((temp,co2), axis=2)  

Y = df_filtered.iloc[:, -144:].to_numpy()

X_test3, Y_test3, Y_pred3, Y_pred_binary3, history3 = train_lstm_model(
    X,
    Y,
    input_shape=(144, 2),
    epochs=100,
    batch_size=16,
    threshold=0.5 
)
# Out:
# Epoch 1/100
# C:\Users\toubia\anaconda3\envs\notebook\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 261ms/step - accuracy: 0.5249 - loss: 0.6855 - val_accuracy: 0.7019 - val_loss: 0.6367
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7463 - loss: 0.6001 - val_accuracy: 0.7023 - val_loss: 0.6356
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7326 - loss: 0.5975 - val_accuracy: 0.7019 - val_loss: 0.6157
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7254 - loss: 0.5905 - val_accuracy: 0.6929 - val_loss: 0.6130
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7387 - loss: 0.5688 - val_accuracy: 0.6955 - val_loss: 0.5946
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7374 - loss: 0.5508 - val_accuracy: 0.7040 - val_loss: 0.5727
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.7459 - loss: 0.5414 - val_accuracy: 0.7061 - val_loss: 0.5721
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7463 - loss: 0.5223 - val_accuracy: 0.7116 - val_loss: 0.5579
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7701 - loss: 0.4925 - val_accuracy: 0.7253 - val_loss: 0.5424
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7666 - loss: 0.4948 - val_accuracy: 0.7177 - val_loss: 0.5365
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7731 - loss: 0.4757 - val_accuracy: 0.7446 - val_loss: 0.5241
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7582 - loss: 0.4815 - val_accuracy: 0.7292 - val_loss: 0.5189
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7794 - loss: 0.4579 - val_accuracy: 0.7632 - val_loss: 0.4856
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8089 - loss: 0.4247 - val_accuracy: 0.7814 - val_loss: 0.4631
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8126 - loss: 0.4061 - val_accuracy: 0.7595 - val_loss: 0.4464
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7989 - loss: 0.3983 - val_accuracy: 0.7767 - val_loss: 0.4314
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8104 - loss: 0.3825 - val_accuracy: 0.8068 - val_loss: 0.4169
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8320 - loss: 0.3639 - val_accuracy: 0.7998 - val_loss: 0.4010
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8266 - loss: 0.3595 - val_accuracy: 0.8177 - val_loss: 0.4090
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8290 - loss: 0.3503 - val_accuracy: 0.8201 - val_loss: 0.3991
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8344 - loss: 0.3561 - val_accuracy: 0.8056 - val_loss: 0.4158
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8349 - loss: 0.3539 - val_accuracy: 0.8220 - val_loss: 0.3890
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8317 - loss: 0.3474 - val_accuracy: 0.8080 - val_loss: 0.3992
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.